# %% [markdown]
# # 04_EDA04_ByPromotions

# %%
import os
import warnings
warnings.filterwarnings("ignore")
import numpy as np 
import pandas as pd 
import sklearn
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples, silhouette_score
# %matplotlib inline

# %%
print(os.getcwd())
os.chdir('/Users/liuyang/Desktop/Springboard_Capstone3/data') 
print(os.getcwd())
# Out:
# /Users/liuyang/Desktop/Springboard_Capstone3/Notebook
# /Users/liuyang/Desktop/Springboard_Capstone3/Data

# %%
newstoredata = pd.read_csv('combined_data.csv')

# %%
import sys
sys.path.insert(1, '/Users/liuyang/Desktop/Springboard_Capstone3/notebook')
import eda

# %%
from eda import data_process, Sales_EDA, sumby, individual_store, combined_storedata, combined_store_EDA

# %% [markdown]
# ## Promo by Store Type

# %%
plt.rcParams['figure.figsize'] = (12, 7)
ax = sns.countplot('StoreType', hue='Promo', data=newstoredata, order= newstoredata['StoreType'].value_counts().index)
ax.set_xlabel('Store Type',fontsize=15)
ax.set_ylabel('Store Count',fontsize=15)
#ax.set_suptitle('Variable vs Target')
ax.legend(['286 Days', '360 Days'])

bars = ax.patches
half = int(len(bars)/2)
left_bars = bars[:half]
right_bars = bars[half:]

for left, right in zip(left_bars, right_bars):
    height_l = left.get_height()
    height_r = right.get_height()


    ax.text(left.get_x() + left.get_width()/2., height_l + 3, '{}'.format(height_l), ha="center",fontsize=13)
    ax.text(right.get_x() + right.get_width()/2., height_r + 3, '{}'.format(height_r), ha="center",fontsize=13)

plt.title('Promo Store Counts by Store Type', fontsize=15)
plt.show()

# %% [markdown]
# ## Promo and Sales

# %%
newstoredata_eda = combined_store_EDA(newstoredata)
newstoredata_eda.type_summary('Promo', 'Sales')
# Out:
# Promo           286           360
# count  1.800000e+02  9.350000e+02
# mean   4.124232e+06  5.487507e+06
# std    1.277245e+06  1.982016e+06
# min    2.306075e+06  2.114322e+06
# 25%    3.316243e+06  4.163445e+06
# 50%    3.866940e+06  5.228649e+06
# 75%    4.760438e+06  6.311646e+06
# max    1.155352e+07  1.951684e+07

# %%
newstoredata_eda.type_violinplot('Sales','Promo')

# %% [markdown]
# ## Promo and AverageDailySales

# %%
newstoredata_eda.type_summary('Promo', 'AverageDailySales')
# Out:
# Promo           286           360
# count    180.000000    935.000000
# mean    6633.909899   6992.019934
# std     2063.888181   2437.454395
# min     3707.516077   2703.736573
# 25%     5331.580788   5319.399815
# 50%     6167.081014   6672.844388
# 75%     7645.617873   8028.343937
# max    18574.795820  21757.483418

# %%
newstoredata_eda.type_violinplot('AverageDailySales','Promo')

# %%
# ## Promo and AverageDailyCustomer

# newstoredata_eda.type_summary('Promo', 'AverageDailyCustomer')

# newstoredata_eda.type_violinplot('AverageDailyCustomer','Promo')

# %% [markdown]
# ## Promo and SalesPerCustomer

# %%
newstoredata_eda.type_summary('Promo', 'SalesPerCustomer')
# Out:
# Promo         286         360
# count  180.000000  935.000000
# mean    10.836935    9.414053
# std      2.000508    1.901108
# min      4.278804    3.513703
# 25%      9.392257    8.032644
# 50%     10.946310    9.250408
# 75%     12.348831   10.692246
# max     16.162639   15.912881

# %%
newstoredata_eda.type_violinplot('SalesPerCustomer','Promo')

# %%
sns.scatterplot(y=newstoredata.Promo,x=newstoredata.AverageDailySales)
plt.show()

# %% [markdown]
# # Stores that had 360 days of promotion (over 942 days) have higher average daily sales than stores that had 286 days of promotion, but slightly lower (1.4 euro) sales per customer than stores that had 286 days of promotions

# %% [markdown]
# ## Promo2 by Store Type
# Promo2 is a continuing and consecutive promotion

# %%
ax = sns.countplot('StoreType', hue='Promo2', data=newstoredata, order= newstoredata['StoreType'].value_counts().index)
ax.set_xlabel('Store Type',fontsize=15)
ax.set_ylabel('Store Count',fontsize=15)
#ax.set_suptitle('Variable vs Target')
ax.legend(['not participating', 'participating'])

bars = ax.patches
half = int(len(bars)/2)
left_bars = bars[:half]
right_bars = bars[half:]

for left, right in zip(left_bars, right_bars):
    height_l = left.get_height()
    height_r = right.get_height()


    ax.text(left.get_x() + left.get_width()/2., height_l + 3, '{}'.format(height_l), ha="center",fontsize=13)
    ax.text(right.get_x() + right.get_width()/2., height_r + 3, '{}'.format(height_r), ha="center",fontsize=13)

plt.title('Promo2 Store Counts by Store Type', fontsize=15)
plt.show()

# %%
ax = sns.countplot('Assortment', hue='Promo2', data=newstoredata, order= newstoredata['Assortment'].value_counts().index)
ax.set_xlabel('Assortment',fontsize=15)
ax.set_ylabel('Count',fontsize=15)
#ax.set_suptitle('Variable vs Target')
ax.legend(['not participating', 'participating'])

bars = ax.patches
half = int(len(bars)/2)
left_bars = bars[:half]
right_bars = bars[half:]

for left, right in zip(left_bars, right_bars):
    height_l = left.get_height()
    height_r = right.get_height()


    ax.text(left.get_x() + left.get_width()/2., height_l + 3, '{}'.format(height_l), ha="center",fontsize=13)
    ax.text(right.get_x() + right.get_width()/2., height_r + 3, '{}'.format(height_r), ha="center",fontsize=13)

plt.title('Promo2 Store Counts by Assortment', fontsize=15)
plt.show()

# %%
newstoredata_eda.type_summary('Promo2', 'Sales')
# Out:
# Promo2             0             1
# count   5.440000e+02  5.710000e+02
# mean    5.719747e+06  4.836494e+06
# std     2.220029e+06  1.537900e+06
# min     2.114322e+06  2.268273e+06
# 25%     4.335896e+06  3.735962e+06
# 50%     5.361383e+06  4.635585e+06
# 75%     6.605908e+06  5.677636e+06
# max     1.951684e+07  1.291178e+07

# %% [markdown]
# ## Promo2 and AverageDailySales

# %%
newstoredata_eda.type_summary('Promo2', 'AverageDailySales')
# Out:
# Promo2             0             1
# count     544.000000    571.000000
# mean     7337.391682   6550.089921
# std      2730.370096   1924.083418
# min      2703.736573   2900.604859
# 25%      5630.471823   5156.033462
# 50%      6936.306575   6267.489060
# 75%      8416.886746   7638.262555
# max     21757.483418  16574.816431

# %%
newstoredata_eda.type_violinplot('AverageDailySales','Promo2')

# %% [markdown]
# ## Promo2 and AverageDailyCustomer

# %%
newstoredata_eda.type_summary('Promo2', 'Sales')
# Out:
# Promo2             0             1
# count   5.440000e+02  5.710000e+02
# mean    5.719747e+06  4.836494e+06
# std     2.220029e+06  1.537900e+06
# min     2.114322e+06  2.268273e+06
# 25%     4.335896e+06  3.735962e+06
# 50%     5.361383e+06  4.635585e+06
# 75%     6.605908e+06  5.677636e+06
# max     1.951684e+07  1.291178e+07

# %%
newstoredata_eda.type_violinplot('AverageDailyCustomer','Promo2')

# %% [markdown]
# ## Promo2 and SalesPerCustomer

# %%
newstoredata_eda.type_summary('Promo2', 'SalesPerCustomer')
# Out:
# Promo2           0           1
# count   544.000000  571.000000
# mean      9.136827   10.126714
# std       1.770858    2.061271
# min       4.025161    3.513703
# 25%       7.896896    8.500811
# 50%       8.973724    9.954110
# 75%      10.298135   11.692336
# max      16.162639   16.068928

# %%
newstoredata_eda.type_violinplot('SalesPerCustomer','Promo2')

# %% [markdown]
# # Stores that doesn't participat in continuing Promo have higher average sales than stores that do participat. Because of the outliers?
# # On the other hand, stores that participate in continuing Promo have higher SalesPerCustomer.

# %%
sns.scatterplot(y=newstoredata.Promo2,x=newstoredata.AverageDailySales)
plt.show()

# %% [markdown]
# ## School Holiday and Sales

# %%
# newstoredata_eda.type_violinplot('AverageDailySales','SchoolHoliday')

# %%
sns.scatterplot(y=newstoredata.SchoolHoliday,x=newstoredata.AverageDailySales)
plt.ylabel('SchoolHoliday', fontsize=14)
plt.xlabel('AverageDailySales', fontsize=14)
plt.show()

# %%
# sns.scatterplot(y=newstoredata.SchoolHoliday,x=newstoredata.AverageDailyCustomer)
# plt.show()

# %%
sns.scatterplot(y=newstoredata.SchoolHoliday,x=newstoredata.SalesPerCustomer)
plt.ylabel('SchoolHoliday', fontsize=14)
plt.xlabel('SalesPerCustomer', fontsize=14)
plt.show()

# %%
sns.scatterplot(y=newstoredata.StateHoliday,x=newstoredata.AverageDailySales)
plt.ylabel('StateHoliday', fontsize=14)
plt.xlabel('AverageDailySales', fontsize=14)
plt.show()

# %%
sns.scatterplot(y=newstoredata.StateHoliday,x=newstoredata.SalesPerCustomer)
plt.ylabel('StateHoliday', fontsize=14)
plt.xlabel('SalesPerCustomer', fontsize=14)
plt.show()

# %%
df = pd.read_csv('train.csv')

# %%
df = df.sort_values(['Date', 'Store'], ascending=True)

# %%
data_process(df).convert_datetime('Date')

# %%
df.head()
# Out:
#          Store  DayOfWeek       Date  Sales  Customers  Open  Promo  \
# 1016095      1          2 2013-01-01      0          0     0      0
# 1016096      2          2 2013-01-01      0          0     0      0
# 1016097      3          2 2013-01-01      0          0     0      0
# 1016098      4          2 2013-01-01      0          0     0      0
# 1016099      5          2 2013-01-01      0          0     0      0
#
#         StateHoliday  SchoolHoliday
# 1016095            a              1
# 1016096            a              1
# 1016097            a              1
# 1016098            a              1
# 1016099            a              1

# %%
data_process(df).str_to_int('StateHoliday')

# %%
df.head()
# Out:
#          Store  DayOfWeek       Date  Sales  Customers  Open  Promo  \
# 1016095      1          2 2013-01-01      0          0     0      0
# 1016096      2          2 2013-01-01      0          0     0      0
# 1016097      3          2 2013-01-01      0          0     0      0
# 1016098      4          2 2013-01-01      0          0     0      0
# 1016099      5          2 2013-01-01      0          0     0      0
#
#          StateHoliday  SchoolHoliday
# 1016095             1              1
# 1016096             1              1
# 1016097             1              1
# 1016098             1              1
# 1016099             1              1

# %%
df.groupby('Store')['StateHoliday'].sum().value_counts().sort_index()
# Out:
# 23      1
# 24    256
# 25     36
# 27    112
# 29    562
# 31     75
# 32     73
# Name: StateHoliday, dtype: int64

# %%
df = df[df.Sales!=0]
df.head()
#df[df.StateHoliday==1].groupby('Date')['Sales'].sum()/df[df.StateHoliday==1].groupby('Date')['Sales'].count()
# Out:
#          Store  DayOfWeek       Date  Sales  Customers  Open  Promo  \
# 1016179     85          2 2013-01-01   4220        619     1      0
# 1016353    259          2 2013-01-01   6851       1444     1      0
# 1016356    262          2 2013-01-01  17267       2875     1      0
# 1016368    274          2 2013-01-01   3102        729     1      0
# 1016429    335          2 2013-01-01   2401        482     1      0
#
#          StateHoliday  SchoolHoliday
# 1016179             1              1
# 1016353             1              1
# 1016356             1              1
# 1016368             1              1
# 1016429             1              1

# %%
# Average daily sales per store when it's a holiday 
df[(df.StateHoliday==1)|(df.SchoolHoliday==1)].groupby('Date')['Sales'].mean().describe()
# Out:
# count      485.000000
# mean      7613.546992
# std       2399.678231
# min       4067.142601
# 25%       5916.958333
# 50%       7137.950000
# 75%       8459.633554
# max      20310.000000
# Name: Sales, dtype: float64

# %%
# Average daily sales per store when it's not holiday 
df[(df.StateHoliday==0)&(df.SchoolHoliday==0)].groupby('Date')['Sales'].mean().describe()
# Out:
# count      889.000000
# mean      7208.007155
# std       1705.916587
# min       4790.063348
# 25%       5780.716592
# 50%       7001.845328
# 75%       8009.492881
# max      14238.588235
# Name: Sales, dtype: float64

# %%
# Average sales per customer when it's a holiday 
(df[(df.StateHoliday==1)|(df.SchoolHoliday==1)].groupby('Date')['Sales'].sum()/df[(df.StateHoliday==1)|(df.SchoolHoliday==1)].groupby('Date')['Customers'].sum()).mean()
# Out:
# 8.589799380197396

# %%
# Average sales per customer when it's a holiday 
(df[(df.StateHoliday==0)|(df.SchoolHoliday==0)].groupby('Date')['Sales'].sum()/df[(df.StateHoliday==0)|(df.SchoolHoliday==0)].groupby('Date')['Customers'].sum()).mean()
# Out:
# 8.529280177447742

# %%
df[(df.StateHoliday==0)&(df.SchoolHoliday==0)]
# Out:
#          Store  DayOfWeek       Date  Sales  Customers  Open  Promo  \
# 1013869      5          4 2013-01-03   3465        491     1      0
# 1013870      6          4 2013-01-03   5398        689     1      0
# 1013919     55          4 2013-01-03   4031        578     1      0
# 1013921     57          4 2013-01-03   9988       1065     1      0
# 1013924     60          4 2013-01-03   5697        587     1      0
# ...        ...        ...        ...    ...        ...   ...    ...
# 1093      1094          5 2015-07-31   5826        425     1      1
# 1101      1102          5 2015-07-31   7211        704     1      1
# 1103      1104          5 2015-07-31   6878        472     1      1
# 1106      1107          5 2015-07-31   9433        825     1      1
# 1108      1109          5 2015-07-31   5263        515     1      1
#
#          StateHoliday  SchoolHoliday
# 1013869             0              0
# 1013870             0              0
# 1013919             0              0
# 1013921             0              0
# 1013924             0              0
# ...               ...            ...
# 1093                0              0
# 1101                0              0
# 1103                0              0
# 1106                0              0
# 1108                0              0
#
# [680297 rows x 9 columns]

# %%
df[(df.StateHoliday==1)|(df.SchoolHoliday==1)].groupby('Date')['Sales'].mean().plot(kind='hist', histtype='step', label='Holiday', lw=2)
df[(df.StateHoliday==0)&(df.SchoolHoliday==0)].groupby('Date')['Sales'].mean().plot(kind='hist', histtype='step', label='Non Holiday', lw=2)
plt.xlabel('Average Sales Per Store', fontsize=20)
plt.yticks(fontsize=20)
plt.xticks(fontsize=18)
plt.ylabel('Day Count', fontsize=20)
plt.legend(fontsize=16)
